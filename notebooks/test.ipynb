# %%
import matplotlib.pyplot as plt

# %%
#!pip install yfinance
#!pip install yahoofinancials

import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

aapl_df = yf.download('AAPL',
                      start='2019-01-01',
                      end='2021-06-12',
                      progress=False,
)
print(aapl_df.head())
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  37.943260  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.163826  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.622253  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.542965  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.220528  164101200
